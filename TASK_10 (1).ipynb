# %% [markdown]
# #EXPLORATORY DATA ANALYSIS#
#
# **Description about Dataset** :- This dataset is taken from *Asprining Mind Employement Outcome 2015(AMEO)*.This table is dedicated to engineering students. This dataset primarily contains the employement outcomes of student,these outcomes are Salary,Job title, Job locations.Along with there score in cognitive skills,technical skills and personality.
#
# The important question is that what determines the salary and the jobs of these engineers right after graduation?So various factors such as college grades,how skilled a candidate is,how much college is near to industrial hubs etc determine the one's job.
#
# This dataset contains demographic features it means it is the study of student based on multiple factors. This dataset contains 40 independent variables and 4000 data points.These independent variables are in categorical and continuous in nature. This dataset also contains unique identifier for each student.This dataset can help us to predict the salary of the candidate by looking up at important features.

# %%
from google.colab import files
a = files.upload()
# Out:
#      <input type="file" id="files-a48317af-3c5f-4577-b4ca-af7545257a7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a48317af-3c5f-4577-b4ca-af7545257a7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data (3).csv

# %% [markdown]
# #IMPORTING LIBRARIES#

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# #DATA EXPLORATION#

# %%
data.head(5)
# Out:
#   Unnamed: 0      ID  ...  nueroticism openess_to_experience
# 0      train  203097  ...      1.35490               -0.4455
# 1      train  579905  ...     -0.10760                0.8637
# 2      train  810601  ...     -0.86820                0.6721
# 3      train  267447  ...     -0.40780               -0.9194
# 4      train  343523  ...      0.09163               -0.1295
#
# [5 rows x 39 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   float64
#  3   DOJ                    3998 non-null   object
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   object
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
# ...

# %%
data.shape
# Out:
# (3998, 39)

# %%
pd.set_option('display.float_format',lambda x:'%.3f'%x)

# %%
data.describe()
# Out:
#                ID      Salary  ...  nueroticism  openess_to_experience
# count    3998.000    3998.000  ...     3998.000               3998.000
# mean   663794.541  307699.850  ...       -0.169                 -0.138
# std    363218.246  212737.500  ...        1.008                  1.008
# min     11244.000   35000.000  ...       -2.643                 -7.376
# 25%    334284.250  180000.000  ...       -0.868                 -0.669
# 50%    639600.000  300000.000  ...       -0.234                 -0.094
# 75%    990480.000  370000.000  ...        0.526                  0.502
# max   1298275.000 4000000.000  ...        3.353                  1.822
#
# [8 rows x 27 columns]

# %%
#Looking at total number of columns present
columns=[]
for i in data.columns:
  columns.append(i)
columns
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Salary',
#  'DOJ',
#  'DOL',
#  'Designation',
#  'JobCity',
#  'Gender',
#  'DOB',
#  '10percentage',
#  '10board',
#  '12graduation',
#  '12percentage',
#  '12board',
#  'CollegeID',
#  'CollegeTier',
#  'Degree',
#  'Specialization',
#  'collegeGPA',
#  'CollegeCityID',
#  'CollegeCityTier',
#  'CollegeState',
#  'GraduationYear',
#  'English',
#  'Logical',
#  'Quant',
#  'Domain',
#  'ComputerProgramming',
#  'ElectronicsAndSemicon',
#  'ComputerScience',
#  'MechanicalEngg',
#  'ElectricalEngg',
#  'TelecomEngg',
#  'CivilEngg',
#  'conscientiousness',
#  'agreeableness',
#  'extraversion',
#  'nueroticism',
#  'openess_to_experience']

# %%
# Checking if any null value is present or not if present it will return True else False
data.isnull().any()
# Out:
# Unnamed: 0               False
# ID                       False
# Salary                   False
# DOJ                      False
# DOL                      False
# Designation              False
# JobCity                  False
# Gender                   False
# DOB                      False
# 10percentage             False
# 10board                  False
# 12graduation             False
# 12percentage             False
# 12board                  False
# CollegeID                False
# CollegeTier              False
# Degree                   False
# Specialization           False
# collegeGPA               False
# CollegeCityID            False
# CollegeCityTier          False
# CollegeState             False
# GraduationYear           False
# English                  False
# Logical                  False
# Quant                    False
# Domain                   False
# ComputerProgramming      False
# ElectronicsAndSemicon    False
# ComputerScience          False
# ...

# %%
#Checking how many unique values are there
for i in columns:
  print("number of unique values in",i,"is = ",len(np.unique(data[i])))
# Out:
# number of unique values in Unnamed: 0 is =  1
# number of unique values in ID is =  3998
# number of unique values in Salary is =  177
# number of unique values in DOJ is =  81
# number of unique values in DOL is =  67
# number of unique values in Designation is =  419
# number of unique values in JobCity is =  339
# number of unique values in Gender is =  2
# number of unique values in DOB is =  1872
# number of unique values in 10percentage is =  851
# number of unique values in 10board is =  275
# number of unique values in 12graduation is =  16
# number of unique values in 12percentage is =  801
# number of unique values in 12board is =  340
# number of unique values in CollegeID is =  1350
# number of unique values in CollegeTier is =  2
# number of unique values in Degree is =  4
# number of unique values in Specialization is =  46
# number of unique values in collegeGPA is =  1282
# number of unique values in CollegeCityID is =  1350
# ...

# %%
data['Designation'].value_counts()
# Out:
# software engineer                      539
# software developer                     265
# system engineer                        205
# programmer analyst                     139
# systems engineer                       118
#                                       ...
# manual tester                            1
# associate manager                        1
# assistant system engineer - trainee      1
# support engineer                         1
# test technician                          1
# Name: Designation, Length: 419, dtype: int64

# %%
data['Degree'].value_counts()
# Out:
# B.Tech/B.E.      3700
# MCA               243
# M.Tech./M.E.       53
# M.Sc. (Tech.)       2
# Name: Degree, dtype: int64

# %%
data['Specialization'].value_counts()
# Out:
# electronics and communication engineering      880
# computer science & engineering                 744
# information technology                         660
# computer engineering                           600
# computer application                           244
# mechanical engineering                         201
# electronics and electrical engineering         196
# electronics & telecommunications               121
# electrical engineering                          82
# electronics & instrumentation eng               32
# civil engineering                               29
# electronics and instrumentation engineering     27
# information science engineering                 27
# instrumentation and control engineering         20
# electronics engineering                         19
# biotechnology                                   15
# other                                           13
# industrial & production engineering             10
# ...

# %% [markdown]
# #**UNIVARIATE ANALYSIS**#
#
# Here in univariate analysis we  are analysing each numerical column.So the question is do we have to analyse each and every column so no here we are only going to analyse the columns that will have some impact on our main ojective i.e. salary

# %%
plt.hist(data['Salary'])
# Out:
# (array([3.398e+03, 5.500e+02, 2.700e+01, 6.000e+00, 8.000e+00, 3.000e+00,
#         2.000e+00, 1.000e+00, 1.000e+00, 2.000e+00]),
#  array([  35000.,  431500.,  828000., 1224500., 1621000., 2017500.,
#         2414000., 2810500., 3207000., 3603500., 4000000.]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(data['Salary'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff72489c9d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff72489fa50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff7248a2a90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff7248a2550>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff72489cf90>,
#   <matplotlib.lines.Line2D at 0x7ff72489f510>]}

# %%
sns.countplot(data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['Salary'].plot.kde()

# %%
sorted(data['Salary'])
q1 = data['Salary'].quantile(0.25)
q3 = data['Salary'].quantile(0.75)
IQR = q3-q1
print(IQR)
print(data['Salary'] < (q1-1.5 * IQR)) or (data['Salary'] > (q3+1.5*IQR))
# Out:
# 190000.0
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3993    False
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# Name: Salary, Length: 3998, dtype: bool
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 3993    False
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# Name: Salary, Length: 3998, dtype: bool

# %% [markdown]
# For Salary Column by doing graphical as well as numerical analysis we can clearly see that there is outliers present first of all see the histogram plot here we are getting one bar like structure and there are small bars we can then infer that the Salary column is having continuous datapoints with some outliers that is further checked by box plot and kde plot. Observe Box plot here you can cleary see that there is so many points that are outside the "maximum" (Q3 + 1.5 *IQR) and in kde  plot you can see that out normal distribution is distorded that completely signifies the presence of outliers and it is negatively skewed. We further cross checked the presence of outliers with the help of IQR(numerical analysis) it had shown False when there is no outlier and True for having an outlier. We can also see that countplot dosen't help us much for continuous data points.So we can say that 'Salary' is skewed to left and needs to be normalised.And one more observation is that very few student get package of more than 6 lac

# %%
plt.hist(data['10percentage'])
# Out:
# (array([ 12.,  50., 132., 240., 446., 636., 811., 850., 677., 144.]),
#  array([43.   , 48.476, 53.952, 59.428, 64.904, 70.38 , 75.856, 81.332,
#         86.808, 92.284, 97.76 ]),
#  <a list of 10 Patch objects>)

# %%
sns.countplot(data['10percentage'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.boxplot(data['10percentage'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff7247fea50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff7243ae190>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff72434e810>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff7243c33d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff724807f10>,
#   <matplotlib.lines.Line2D at 0x7ff72434a090>]}

# %%
data['10percentage'].plot.kde()

# %%
sorted(data['10percentage'])
q1 = data['10percentage'].quantile(0.25)
q3 = data['10percentage'].quantile(0.75)
IQR = q3-q1
print(IQR)
print(data['10percentage'] < (q1-1.5 * IQR)) or (data['Salary'] > (q3+1.5*IQR))
# Out:
# 13.990000000000009
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3993    False
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# Name: 10percentage, Length: 3998, dtype: bool
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3993    True
# 3994    True
# 3995    True
# 3996    True
# 3997    True
# Name: Salary, Length: 3998, dtype: bool

# %% [markdown]
# For '10 percentage' Column by doing graphical as well as numerical analysis we can clearly see that there is outliers present first of all see the histogram plot here we are getting plot that is very shifted  and there are small bars to the left side of graph we can then infer that the column is having continuous datapoints with some outliers that is further checked by box plot and kde plot. Observe Box plot here you can cleary see that there is so many points that are outside the "minimum" (Q1 - 1.5 *IQR) and in kde  plot you can see that out normal distribution is distorded that completely signifies the presence of outliers and it is positively skewed. We further cross checked the presence of outliers with the help of IQR(numerical analysis) it had shown False when there is no outlier and True for having an outlier. We can also see that countplot dosen't help us much for continuous data points.So we can say that '10percentage' is skewed to right and needs to be normalised.It can be seen that very few student get percentage less than 50 , average student percentage is 80.

# %%
plt.hist(data['12percentage'])
# Out:
# (array([  8.,  55., 160., 489., 657., 768., 696., 551., 413., 201.]),
#  array([40.  , 45.87, 51.74, 57.61, 63.48, 69.35, 75.22, 81.09, 86.96,
#         92.83, 98.7 ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(data['12percentage'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff720c84ed0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff720c8af10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff720e67f50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff720e67a10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff720c8a490>,
#   <matplotlib.lines.Line2D at 0x7ff720c8a9d0>]}

# %%
sns.countplot(data['12percentage'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['12percentage'].plot.kde()

# %% [markdown]
# For '12 percentage' Column by doing graphical analysis we can clearly see that there is outliers present first of all see the histogram plot here we are getting plot that is very shifted  and there are small bars to the left side of graph we can then infer that the column is having continuous datapoints with some outliers,but it is somewhat smooth, that is further checked by box plot and kde plot. Observe Box plot here you can cleary see that there is one point that is outside the "minimum" (Q1 - 1.5 *IQR) and in kde  plot you can see that it is normal distribution. We can also see that countplot dosen't help us much for continuous data points.On an average student get 75.

# %%
data['CollegeTier'].value_counts()
# Out:
# 2    3701
# 1     297
# Name: CollegeTier, dtype: int64

# %%
sns.boxplot(data['CollegeTier'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(data['CollegeTier'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(data['CollegeTier'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['CollegeCityTier'].value_counts()
# Out:
# 0    2797
# 1    1201
# Name: CollegeCityTier, dtype: int64

# %%
sns.violinplot(data['CollegeCityTier'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.boxplot(data['CollegeCityTier'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff71f6bb190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff71f6c21d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff71f6cb210>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff71f6c2c90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff71f6bb710>,
#   <matplotlib.lines.Line2D at 0x7ff71f6bbc50>]}

# %%
sns.barplot(data['CollegeCityTier'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['CollegeCityTier'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# For college Tier and College city tier both come as a categorical column here in college tier we have 1,2 as the outcomes and we had plotted this and we can infer that 1 has less less probability than 2. And in college city tier we can infer that here it have outcome 1 and 0 and 1  have less probability.

# %%
(data[['English','Logical','Quant','ComputerProgramming','ElectronicsAndSemicon']]).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff71f613e50>,
# ...
#       dtype=object)

# %%
(data[['English','Logical','Quant','ComputerProgramming','ElectronicsAndSemicon']]).boxplot(figsize=(16,12))

# %%
(data[['English','Logical','Quant','ComputerProgramming','ElectronicsAndSemicon']]).plot.kde(figsize=(16,12))

# %% [markdown]
# Now we here analysed all the subjects i.e 'english','logical','quant','Computer programming' and 'Electronics and semiconductor'. As we can see from all the above plots that outliers is present here in all the mentioned columns. As for mentioned data points it is skewed either to left or right as in box plot the outliers are clearly seen. As well as by seeing the electronics and semicon hist plot here are some missing values too that need to be imputed by mean/median.
# * english,logical,quant - outliers are present on both side and they are normally distributed.
# * computer programming , electronics and semicon - are bimodal.

# %%
(data[['ComputerScience','MechanicalEngg','ElectricalEngg','TelecomEngg','CivilEngg']]).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff71f1ad410>,
# ...
#       dtype=object)

# %%
(data[['ComputerScience','MechanicalEngg','ElectricalEngg','TelecomEngg','CivilEngg']]).boxplot(figsize=(16,16))

# %%
(data[['ComputerScience','MechanicalEngg','ElectricalEngg','TelecomEngg','CivilEngg']]).plot.kde(figsize=(8,8))

# %% [markdown]
# Here the data points have many outliers and due to this they are skewed and needs to be normalised.
# * computer science - more than 3000 student ia having 0 marks.
# * mechanical, electrical and telecommunicatiom - less studemt get good marks ,more than 3500 student gets fail and these subjects are toughest.
# * civil - average marks is 0 stating that is very tough.

# %%
(data[['conscientiousness','agreeableness','extraversion','nueroticism','openess_to_experience']]).hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff71d5a4c90>,
# ...
#       dtype=object)

# %%
(data[['conscientiousness','agreeableness','extraversion','nueroticism','openess_to_experience']]).boxplot(figsize=(8,8))

# %%
(data[['conscientiousness','agreeableness','extraversion','nueroticism','openess_to_experience']]).plot.kde(figsize=(8,8))

# %% [markdown]
# 'openess_to_experience','extraversion','conscientiousness','agreeableness' these datapoints are positively skewed and 'nueroticis' is negatively skewed as we can see from the hist, box and kde plot.

# %%
plt.hist(data['Domain'])
# Out:
# (array([ 246.,    0.,    0.,    0.,    0.,  339.,  658.,  604.,  975.,
#         1176.]),
#  array([-1.00000000e+00, -8.00008959e-01, -6.00017918e-01, -4.00026878e-01,
#         -2.00035837e-01, -4.47960000e-05,  1.99946245e-01,  3.99937286e-01,
#          5.99928326e-01,  7.99919367e-01,  9.99910408e-01]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(data['Domain'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff71d124f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff71d12bf50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff71d133f90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff71d133a50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff71d12b4d0>,
#   <matplotlib.lines.Line2D at 0x7ff71d12ba10>]}

# %%
sns.countplot(data['Domain'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['Domain'].plot.kde()

# %% [markdown]
# Clearly can see that 'domain' is positively skewed and it is having some missing points too.

# %%
data['collegeGPA'].hist()

# %%
plt.boxplot(data['collegeGPA'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff71c9b8d10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff71c9c1d50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff71c9c7d90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff71c9c7850>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff71c9c12d0>,
#   <matplotlib.lines.Line2D at 0x7ff71c9c1810>]}

# %%
sns.countplot(data['collegeGPA'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data['collegeGPA'].plot.kde()

# %% [markdown]
# 'college GPA' plot is normally distributed there is some outliers due to which there is skewness that is seen in kde and box plot but it is due to the fact that some gpas are out of 10 and they need to be multilplied by 10 so by this we are remove the effect of outlier here.

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %% [markdown]
# Bivariate analysis means analyzing 2 variables.
# It is of 3 types:-
#
# * Numerical vs Numerical
# * Categorical vs Numerical
# * Categorical vs categorical
#
# here our main focus is to compare salary with other variables

# %%
# salary Vs Gender
plt.plot(data['Gender'],data['Salary'],'r.')

# %%
sns.boxplot(data['Gender'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot(data['Gender'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 81.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 91.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data.pivot_table(values='Salary',index='Gender')
# Out:
#            Salary
# Gender
# f      294937.304
# m      311716.212

# %% [markdown]
# By seeing all the plots that there is not much difference between the Salary of male and female generally but for high packages male are choosen.We had then confirmed this thing from pivot table

# %%
# Going to see which board student have high salary
sns.scatterplot(data['12board'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data['12board'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.pivot_table(values='Salary',index='12board')
# Out:
#                                                        Salary
# 12board
#  board of intermediate                             162500.000
#  upboard                                           150000.000
# 0                                                  377590.529
# ahsec                                              450000.000
# aissce                                             165000.000
# ...                                                       ...
# west bengal board of higher secondary education    250000.000
# west bengal council of higher secondary education  373000.000
# west bengal council of higher secondary eucation   365000.000
# west bengal council of higher secondary examina... 470000.000
# west bengal state council of technical education   100000.000
#
# [340 rows x 1 columns]

# %% [markdown]
# We can infer that peak value is shown by icse student then cbse student and then the state board

# %%
#here we are going to see which state college candiadates get more salary

sns.scatterplot(data['CollegeState'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data['CollegeState'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data['CollegeState'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.pivot_table(values='Salary',index='CollegeState')
# Out:
#                       Salary
# CollegeState
# Andhra Pradesh    324488.889
# Assam             452000.000
# Bihar             287000.000
# Chhattisgarh      261666.667
# Delhi             363179.012
# Goa               450000.000
# Gujarat           321666.667
# Haryana           299916.667
# Himachal Pradesh  320312.500
# Jammu and Kashmir 396428.571
# Jharkhand         479285.714
# Karnataka         324310.811
# Kerala            278030.303
# Madhya Pradesh    331137.566
# Maharashtra       301545.802
# Meghalaya         537500.000
# Orissa            310203.488
# Punjab            304663.212
# Rajasthan         319626.437
# Sikkim            360000.000
# Tamil Nadu        280694.823
# Telangana         300344.828
# Union Territory   186000.000
# Uttar Pradesh     298966.120
# Uttarakhand       302300.885
# West Bengal       278137.755

# %% [markdown]
# Clearly it can be seen that Assam and Jharkhand have high mean Salaries

# %%
# Which degree holder is getting more salary?
sns.scatterplot(data['Degree'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data['Degree'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data['Degree'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.pivot_table(values='Salary',index='Degree')
# Out:
#                   Salary
# Degree
# B.Tech/B.E.   308622.703
# M.Sc. (Tech.) 320000.000
# M.Tech./M.E.  366132.075
# MCA           280802.469

# %% [markdown]
# B.tech / B.E degree holder is getting more salary as compared to other degrees

# %%
#CollegeTier vs salary
sns.scatterplot(data['CollegeTier'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(data['CollegeTier'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.stripplot(data['CollegeTier'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.pivot_table(values='Salary',index='CollegeTier')
# Out:
#                 Salary
# CollegeTier
# 1           442356.902
# 2           296893.812

# %% [markdown]
# There is huge difference between the salary of 1st and 2nd tier college student.

# %%
sns.scatterplot(data['Designation'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.stripplot(data['Designation'],data['Salary'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.pivot_table(values='Salary',index='Designation')
# Out:
#                                   Salary
# Designation
# .net developer                223382.353
# .net web developer            196250.000
# account executive             287500.000
# account manager               350000.000
# admin assistant               102500.000
# ...                                  ...
# web designer and seo          200000.000
# web developer                 168981.481
# web intern                    205000.000
# website developer/tester      200000.000
# windows systems administrator 200000.000
#
# [419 rows x 1 columns]

# %% [markdown]
# As there are 419 rows so we can't  say exactly that which designation holder will have more salary

# %% [markdown]
# #**RESEARCH QUESTIONS**#
#
# Times of India article dated Jan 18,2019 states that "After doingYour Computer Science Engineering if you take up jobs as a Programming Analyst , Software Engineer, Hardware Engineer and Associate Engineer we can earn upto 2.5- 3 lakhs as a fresh graduate . Test this claim with the data given below

# %%
# We can solve this question in two ways First way is to compute the avg salary of an Computer science engineers.
#And the 2nd way is to compute average salaries of these domains stated in the question
# Start 1st method
data['Specialization'].value_counts()
# Out:
# electronics and communication engineering      880
# computer science & engineering                 744
# information technology                         660
# computer engineering                           600
# computer application                           244
# mechanical engineering                         201
# electronics and electrical engineering         196
# electronics & telecommunications               121
# electrical engineering                          82
# electronics & instrumentation eng               32
# civil engineering                               29
# electronics and instrumentation engineering     27
# information science engineering                 27
# instrumentation and control engineering         20
# electronics engineering                         19
# biotechnology                                   15
# other                                           13
# industrial & production engineering             10
# ...

# %%
# Here we have so many Specialization that is related to each other we will merge similar kind of specialization into one group
from pandas import Series
S = Series(['computer engineering','computer science','information science','computer science & engineering','information technology',    
'computer application','information science engineering','computer science and technology'])
data.loc[data['Specialization'].isin(S),'Specialization'] = 'Computer science engineering'

# %%
S = Series(['electronics and electrical engineering','electrical engineering'])
data.loc[data['Specialization'].isin(S),'Specialization'] = 'EEE engineering'

# %%
S = Series(['','information & communication technology','electronics and communication engineering','electronics & telecommunications','electronics & instrumentation eng',    
'electronics and instrumentation engineering','electronics engineering','telecommuunication engineering'])
data.loc[data['Specialization'].isin(S),'Specialization'] = 'ECE engineering'

# %%
S = Series(['Computer science engineering','EEE engineering','ECE engineering','mechanical engineering','civil engineering'])
data.loc[-data['Specialization'].isin(S),'Specialization'] = 'other'

# %%
data.pivot_table(values='Salary',index='Specialization')
# Out:
#                                      Salary
# Specialization
# Computer science engineering  312114.711033
# ECE engineering               299079.555967
# EEE engineering               288938.848921
# civil engineering             381206.896552
# mechanical engineering        317457.711443
# other                         310560.000000

# %% [markdown]
# We have here just merged all the related fields into one fields like all the specialization that is related to computer science engineering we had merged them all and like wise we had done for ece and eee too so that we can compare there mean salaries to cse cadidate but as our question was related to cse student we can see that yes there avg salary is around 3.1 lakh that is very near to Times of India bold claim.

# %%
#Second way to proof this thing
data['Designation'].value_counts()
# Out:
# software engineer                      539
# software developer                     265
# system engineer                        205
# programmer analyst                     139
# systems engineer                       118
#                                       ...
# manual tester                            1
# associate manager                        1
# assistant system engineer - trainee      1
# support engineer                         1
# test technician                          1
# Name: Designation, Length: 419, dtype: int64

# %%
from pandas import Series
S= Series(['programmer analyst','software engineer','hardware engineer','associate engineer'])
data.loc[data['Designation'].isin(S),'Designation'] = 'computer science'

# %%
S= Series(['computer science'])
data.loc[-data['Designation'].isin(S),'Designation'] = 'other'

# %%
data.pivot_table(values='Salary',index='Designation')
# Out:
#                          Salary
# Designation
# computer science  339790.462428
# other             300982.758621

# %% [markdown]
# Here also average Salary is around 3 lakh that stated the Times of India bold claim is true

# %% [markdown]
# Next question is that is there any relation between gender and specialisation.Do people choose there field as per to there gender

# %%
# Let's first try to do Bivariate analysis here to proof the claim (Categorical vs categorical)
sns.histplot(binwidth=0.5,x='Gender',hue='Specialization',data=data,stat='count',multiple='stack')

# %% [markdown]
# Yes we can see that the specilization is choosen as per to gender. Females are taking more CSE,ECE fields as compared to other fields.

# %%
data['Gender'].value_counts()
# Out:
# m    3041
# f     957
# Name: Gender, dtype: int64

# %%
data['Specialization'].value_counts()
# Out:
# Computer science engineering    2284
# ECE engineering                 1081
# EEE engineering                  278
# mechanical engineering           201
# other                            125
# civil engineering                 29
# Name: Specialization, dtype: int64

# %%
pd.crosstab(data.Specialization,data.Gender,margins=True)
# Out:
# Gender                          f     m   All
# Specialization
# Computer science engineering  601  1683  2284
# ECE engineering               260   821  1081
# EEE engineering                51   227   278
# civil engineering               6    23    29
# mechanical engineering         10   191   201
# other                          29    96   125
# All                           957  3041  3998

# %%
observed=pd.crosstab(data.Specialization,data.Gender)
observed
# Out:
# Gender                          f     m
# Specialization
# Computer science engineering  601  1683
# ECE engineering               260   821
# EEE engineering                51   227
# civil engineering               6    23
# mechanical engineering         10   191
# other                          29    96

# %%
from scipy.stats import chi2
from scipy.stats import chi2_contingency
chi2_contingency(observed)
# Out:
# (51.76502944562292,
#  6.027788229324606e-10,
#  5,
#  array([[ 546.72036018, 1737.27963982],
#         [ 258.75862931,  822.24137069],
#         [  66.54477239,  211.45522761],
#         [   6.94172086,   22.05827914],
#         [  48.11330665,  152.88669335],
#         [  29.92121061,   95.07878939]]))

# %%
chi2_test_stat= chi2_contingency(observed)[0]
pval = chi2_contingency(observed)[1]
data1 = chi2_contingency(observed)[2]

# %%
cl = 0.95
alpha = 1- cl
chi2_critical = chi2.ppf(1-alpha,data1)
chi2_critical
# Out:
# 11.070497693516351

# %%
x_min = 0
x_max =100

x = np.linspace(x_min,x_max,100)
y= chi2.pdf(x,data1)
plt.xlim(x_min,x_max)
plt.plot(x,y)

chi2_critical_right = chi2_critical

x1= np.linspace(chi2_critical_right,x_max,100)
y1 = chi2.pdf(x1,data1)
plt.fill_between(x1,y1,color='red')

# %%
if (chi2_test_stat > chi2_critical):
  print("Reject Null Hypothesis")
else:
  print("Fail to reject null hypothesis")
# Out:
# Reject Null Hypothesis

# %%
if (pval < alpha):
  print("Reject Null Hypothesis")
else:
  print("Fail to reject null hypothesis")
# Out:
# Reject Null Hypothesis

# %% [markdown]
# #Conclusion#
#
# * Females are choosing Ece and cse branches.
# * college 1 tier have more placements compared to second.
# * More number of males are hired as compared to females.
# * Salary difference between male and female is not much.
# * There is very rare change in the % from 10th to 12th.
# * CIVIL is the toughest branch.

# %% [markdown]
# Research question we can ask here that how can we state that on an average 2nd tier college student get less salary as compared to 1st tiercollege student.

# %% [markdown]
# #Feature Transformation#

# %%
data['Gender'].value_counts()
# Out:
# m    3041
# f     957
# Name: Gender, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
columns = ['Gender','Degree','12board','10board','Specialization','JobCity','Designation','CollegeState']
for i in columns:
  le = LabelEncoder()
  data[i] = le.fit_transform(data[i])

# %%
data.head()
# Out:
#   Unnamed: 0      ID  ...  nueroticism openess_to_experience
# 0      train  203097  ...      1.35490               -0.4455
# 1      train  579905  ...     -0.10760                0.8637
# 2      train  810601  ...     -0.86820                0.6721
# 3      train  267447  ...     -0.40780               -0.9194
# 4      train  343523  ...      0.09163               -0.1295
#
# [5 rows x 39 columns]

# %%
data.drop('DOJ',inplace=True,axis=1)

# %%
data.drop('DOL',inplace=True,axis=1)
data.drop('DOB',inplace=True,axis=1)

# %%
data.drop('Unnamed: 0',inplace=True,axis=1)
data.drop('ID',inplace=True,axis=1)

# %%
data.head()
# Out:
#       Salary  Designation  ...  nueroticism  openess_to_experience
# 0   420000.0            0  ...      1.35490                -0.4455
# 1   500000.0            1  ...     -0.10760                 0.8637
# 2   325000.0            0  ...     -0.86820                 0.6721
# 3  1100000.0            1  ...     -0.40780                -0.9194
# 4   200000.0            1  ...      0.09163                -0.1295
#
# [5 rows x 34 columns]

# %%
data.shape
# Out:
# (3998, 34)

# %%
from sklearn.preprocessing import StandardScaler

data.iloc[:,0:34] = StandardScaler().fit_transform(data.iloc[:,0:34])

# %%
data.head()
# Out:
#      Salary  Designation  ...  nueroticism  openess_to_experience
# 0  0.527947    -1.782593  ...     1.512658              -0.304966
# 1  0.904045     0.560980  ...     0.060978               0.993910
# 2  0.081332    -1.782593  ...    -0.693995               0.803821
# 3  3.724775     0.560980  ...    -0.237001              -0.775129
# 4 -0.506320     0.560980  ...     0.258734               0.008542
#
# [5 rows x 34 columns]
